# %%
import tkinter as tk

# Definisi fungsi-fungsi
def tambah():
    global angka1, angka2, hasil
    angka2 = float(input_angka2.get())
    hasil = angka1 + angka2
    output.configure(text=f"{angka1} + {angka2} = {hasil}")

def kurang():
    global angka1, angka2, hasil
    angka2 = float(input_angka2.get())
    hasil = angka1 - angka2
    output.configure(text=f"{angka1} - {angka2} = {hasil}")

def kali():
    global angka1, angka2, hasil
    angka2 = float(input_angka2.get())
    hasil = angka1 * angka2
    output.configure(text=f"{angka1} * {angka2} = {hasil}")

def bagi():
    global angka1, angka2, hasil
    angka2 = float(input_angka2.get())
    hasil = angka1 / angka2
    output.configure(text=f"{angka1} / {angka2} = {hasil}")

# Inisialisasi variabel
angka1 = 0
angka2 = 0
hasil = 0

# Buatlah window
window = tk.Tk()
window.title("Kalkulator")
window.geometry("300x200")

# Buatlah label
label_angka1 = tk.Label(window, text="Angka 1")
label_angka1.grid(row=0, column=0)

input_angka1 = tk.Entry(window)
input_angka1.grid(row=0, column=1)

label_operator = tk.Label(window, text="Operator")
label_operator.grid(row=1, column=0)

label_angka2 = tk.Label(window, text="Angka 2")
label_angka2.grid(row=2, column=0)

input_angka2 = tk.Entry(window)
input_angka2.grid(row=2, column=1)

label_hasil = tk.Label(window, text="Hasil")
label_hasil.grid(row=3, column=0)

output = tk.Label(window, text="0")
output.grid(row=3, column=1)

# Buatlah button
button_tambah = tk.Button(window, text="+", command=tambah)
button_tambah.grid(row=4, column=0)

button_kurang = tk.Button(window, text="-", command=kurang)
button_kurang.grid(row=4, column=1)

button_kali = tk.Button(window, text="*", command=kali)
button_kali.grid(row=5, column=0)

button_bagi = tk.Button(window, text="/", command=bagi)
button_bagi.grid(row=5, column=1)

# Jalankan window
window.mainloop()

# %%
import pyttsx3

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
# you can use print(voices) to see how many voices you have installed
# print(voices[0].id)
# print(voices[1].id)
# print(voices[2].id)
print(voices)
engine.setProperty('voice', voices[0].id)

def speak(audio):
    print(audio)  # Fix the indentation here
    engine.say(audio)
    engine.runAndWait()

speak('Drag and drop your files, or type, paste, and edit text here.

Natural Reader is a professional text-to-speech program that converts any written text into spoken words.

We have both free and paid subscriptions to our applications to meet different users' needs on different budgets. Our Plus + subscription includes exclusive features and the use of Plus Voices, our newest and most advanced voices. Plus Voices enable fluid and natural-sounding text to speech that matches the patterns and intonation of human voices.

Free users can sample the Premium Voices for 20 minutes per day and the Plus Voices for 5 minutes per day. Or use any available Free Voices unlimitedly.

You can also listen and go with our mobile app. By using the mobile camera, you can even use our app to listen to physical books and notes.

If you are interested in using our voices for non-personal use such as for Youtube videos, e-Learning, or other commercial or public purposes, please check out our Natural Reader AI Voice Generator web application.

Our Chrome extension allows you to listen to webpages, Google Docs, online Kindle books, and emails directly from the browser. Add it to Chrome for free.')

# prints hello and says it

### ---- (-: Happy Coding :-) ---- ###
# Signing off,
# Ninja Hatori Cat Codr (https://github.com/PrathameshBhatkar)
#                       (https://www.youtube.com/channel/UCHzOI93T5ZZ4TqYJqz6WmYQ)
# Out:
#   Cell In[5], line 17
#     speak('Drag and drop your files, or type, paste, and edit text here.
#           ^
# SyntaxError: unterminated string literal (detected at line 17)

# %%
import pyttsx3

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
# you can use print(voices) to see how many voices you have installed
# print(voices[0].id)
# print(voices[1].id)
# print(voices[2].id)
print(voices)
engine.setProperty('voice', voices[0].id)

def speak(audio):
    print(audio)  # Fix the indentation here
    engine.say(audio)
    engine.runAndWait()

text_to_read = """
Drag and drop your files, or type, paste, and edit text here.

Natural Reader is a professional text-to-speech program that converts any written text into spoken words.

We have both free and paid subscriptions to our applications to meet different users' needs on different budgets. Our Plus subscription includes exclusive features and the use of Plus Voices, our newest and most advanced voices. Plus Voices enable fluid and natural-sounding text to speech that matches the patterns and intonation of human voices.

Free users can sample the Premium Voices for 20 minutes per day and the Plus Voices for 5 minutes per day. Or use any available Free Voices unlimitedly.

You can also listen and go with our mobile app. By using the mobile camera, you can even use our app to listen to physical books and notes.

If you are interested in using our voices for non-personal use such as for Youtube videos, e-Learning, or other commercial or public purposes, please check out our Natural Reader AI Voice Generator web application.

Our Chrome extension allows you to listen to webpages, Google Docs, online Kindle books, and emails directly from the browser. Add it to Chrome for free.
"""

speak(text_to_read)

# prints hello and says it

### ---- (-: Happy Coding :-) ---- ###
# Signing off,
# Ninja Hatori Cat Codr (https://github.com/PrathameshBhatkar)
#                       (https://www.youtube.com/channel/UCHzOI93T5ZZ4TqYJqz6WmYQ)

# %%
import pyttsx3
from pydub import AudioSegment
from pydub.playback import play

def speak_and_export(audio, output_file):
    engine = pyttsx3.init('sapi5')
    voices = engine.getProperty('voices')
    engine.setProperty('voice', voices[0].id)

    # Save the speech to an MP3 file
    mp3_file = output_file + ".mp3"
    engine.save_to_file(audio, mp3_file)
    engine.runAndWait()

    # Load the MP3 file and export it as WAV
    sound = AudioSegment.from_mp3(mp3_file)
    sound.export(output_file, format="wav")

# Example usage
text_to_read = """Drag and drop your files, or type, paste, and edit text here.

Natural Reader is a professional text-to-speech program that converts any written text into spoken words.

We have both free and paid subscriptions to our applications to meet different users' needs on different budgets. Our Plus subscription includes exclusive features and the use of Plus Voices, our newest and most advanced voices. Plus Voices enable fluid and natural-sounding text to speech that matches the patterns and intonation of human voices.

Free users can sample the Premium Voices for 20 minutes per day and the Plus Voices for 5 minutes per day. Or use any available Free Voices unlimitedly.

You can also listen and go with our mobile app. By using the mobile camera, you can even use our app to listen to physical books and notes.

If you are interested in using our voices for non-personal use such as for Youtube videos, e-Learning, or other commercial or public purposes, please check out our Natural Reader AI Voice Generator web application.

Our Chrome extension allows you to listen to webpages, Google Docs, online Kindle books, and emails directly from the browser. Add it to Chrome for free."""
output_file = "output1"

speak_and_export(text_to_read, output_file)
# Out:
# C:\Users\ghani\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# C:\Users\ghani\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pydub\utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 35
#      20 text_to_read = """Drag and drop your files, or type, paste, and edit text here.
#      21
# ...
